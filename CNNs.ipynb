# %%
import numpy as np
import tensorflow as tf
import os
import cv2
from tensorflow.keras.layers import Dense, Flatten , Activation , Conv2D , MaxPooling2D, Dropout
from tensorflow.keras.models import Sequential
import pickle
from tensorflow.keras.callbacks import TensorBoard
import time
import time

NAME="Cats-vs-Dogs-64x2-CNN-{}".format(int(time.time()))
x = pickle.load(open("x.pickle","rb"))
y = pickle.load(open("y.pickle","rb"))
y=np.array(y)
x=x/255.0

dense_layers=[0,1,2]
layer_sizes=[32,64,128]
conv_layers=[1,2,3]

for dense_layer in dense_layers:
    for layer_size in layer_sizes:
        for conv_layer in conv_layers:
            NAME="{}-conv-{}-nodes-{}-dense-{}".format(conv_layer, layer_size, dense_layer,int(time.time()))
            tensorboard= TensorBoard(log_dir="logs/{}".format(NAME))
            print(NAME)
            model= Sequential()
            model.add(Conv2D(64, (3,3), input_shape= x.shape[1:] ))
            model.add(Activation("relu"))
            model.add(MaxPooling2D(pool_size=(2,2)))

            for l in range(conv_layer-1):  
                model.add(Conv2D(layer_size, (3,3)))
                model.add(Activation("relu"))
                model.add(MaxPooling2D(pool_size=(2,2)))
            
            model.add(Flatten())
            for l in range(dense_layer):
                model.add(Dense(layer_size))
                model.add(Activation("relu"))
            
            model.add(Dense(1))
            model.add(Activation("sigmoid"))
            
            model.compile(optimizer="adam", loss= "binary_crossentropy",metrics=["accuracy"])
            model.fit(x,y, batch_size= 32 , validation_split= 0.1, epochs = 3, callbacks=[tensorboard])
# Out:
# 1-conv-32-nodes-0-dense-1729831954
# Epoch 1/3
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 15s 19ms/step - accuracy: 0.6307 - loss: 0.6484 - val_accuracy: 0.6810 - val_loss: 0.5965
# Epoch 2/3
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.7477 - loss: 0.5167 - val_accuracy: 0.7455 - val_loss: 0.5297
# Epoch 3/3
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.7849 - loss: 0.4614 - val_accuracy: 0.7395 - val_loss: 0.5279
# 2-conv-32-nodes-0-dense-1729831997
# Epoch 1/3
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 22s 30ms/step - accuracy: 0.5883 - loss: 0.6579 - val_accuracy: 0.7122 - val_loss: 0.5502
# Epoch 2/3
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 21s 29ms/step - accuracy: 0.7342 - loss: 0.5295 - val_accuracy: 0.7555 - val_loss: 0.5022
# Epoch 3/3
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 22s 31ms/step - accuracy: 0.7761 - loss: 0.4699 - val_accuracy: 0.7695 - val_loss: 0.4848
# 3-conv-32-nodes-0-dense-1729832062
# Epoch 1/3
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 27s 37ms/step - accuracy: 0.5796 - loss: 0.6642 - val_accuracy: 0.7319 - val_loss: 0.5475
# Epoch 2/3
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 24s 34ms/step - accuracy: 0.7357 - loss: 0.5315 - val_accuracy: 0.7563 - val_loss: 0.5013
# Epoch 3/3
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 26s 36ms/step - accuracy: 0.7786 - loss: 0.4616 - val_accuracy: 0.7964 - val_loss: 0.4485
# 1-conv-64-nodes-0-dense-1729832139
# Epoch 1/3
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.6340 - loss: 0.6549 - val_accuracy: 0.7307 - val_loss: 0.5522
# Epoch 2/3
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.7580 - loss: 0.5059 - val_accuracy: 0.7194 - val_loss: 0.5437
# Epoch 3/3
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 14s 19ms/step - accuracy: 0.7875 - loss: 0.4598 - val_accuracy: 0.7391 - val_loss: 0.5378
# 2-conv-64-nodes-0-dense-1729832181
# Epoch 1/3
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 33s 46ms/step - accuracy: 0.6075 - loss: 0.6576 - val_accuracy: 0.7214 - val_loss: 0.5781
# Epoch 2/3
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 33s 46ms/step - accuracy: 0.7375 - loss: 0.5369 - val_accuracy: 0.7623 - val_loss: 0.4899
# Epoch 3/3
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 35s 49ms/step - accuracy: 0.7802 - loss: 0.4669 - val_accuracy: 0.7796 - val_loss: 0.4740
# 3-conv-64-nodes-0-dense-1729832282
# Epoch 1/3
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 35s 50ms/step - accuracy: 0.5990 - loss: 0.6525 - val_accuracy: 0.7279 - val_loss: 0.5282
# Epoch 2/3
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 35s 50ms/step - accuracy: 0.7608 - loss: 0.4920 - val_accuracy: 0.8016 - val_loss: 0.4292
# Epoch 3/3
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 34s 48ms/step - accuracy: 0.8062 - loss: 0.4197 - val_accuracy: 0.8004 - val_loss: 0.4241
# 1-conv-128-nodes-0-dense-1729832387
# Epoch 1/3
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 13s 18ms/step - accuracy: 0.6148 - loss: 0.6740 - val_accuracy: 0.7210 - val_loss: 0.5571
# Epoch 2/3
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 13s 19ms/step - accuracy: 0.7562 - loss: 0.5102 - val_accuracy: 0.7335 - val_loss: 0.5325
# Epoch 3/3
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.7881 - loss: 0.4589 - val_accuracy: 0.7198 - val_loss: 0.5656
# 2-conv-128-nodes-0-dense-1729832428
# Epoch 1/3
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 53s 75ms/step - accuracy: 0.6210 - loss: 0.6416 - val_accuracy: 0.7287 - val_loss: 0.5460
# Epoch 2/3
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 52s 75ms/step - accuracy: 0.7630 - loss: 0.4941 - val_accuracy: 0.7695 - val_loss: 0.4815
# Epoch 3/3
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 51s 72ms/step - accuracy: 0.7988 - loss: 0.4360 - val_accuracy: 0.7884 - val_loss: 0.4592
# 3-conv-128-nodes-0-dense-1729832585
# Epoch 1/3
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 65s 91ms/step - accuracy: 0.5656 - loss: 0.6734 - val_accuracy: 0.7138 - val_loss: 0.5736
# Epoch 2/3
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 66s 94ms/step - accuracy: 0.7570 - loss: 0.4998 - val_accuracy: 0.7948 - val_loss: 0.4638
# Epoch 3/3
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 67s 95ms/step - accuracy: 0.8121 - loss: 0.4148 - val_accuracy: 0.8120 - val_loss: 0.4146
# 1-conv-32-nodes-1-dense-1729832782
# Epoch 1/3
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 20s 28ms/step - accuracy: 0.6303 - loss: 0.6845 - val_accuracy: 0.7375 - val_loss: 0.5359
# Epoch 2/3
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 21s 30ms/step - accuracy: 0.7773 - loss: 0.4751 - val_accuracy: 0.7447 - val_loss: 0.5308
# Epoch 3/3
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 22s 32ms/step - accuracy: 0.8178 - loss: 0.4079 - val_accuracy: 0.7483 - val_loss: 0.5333
# 2-conv-32-nodes-1-dense-1729832846
# Epoch 1/3
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 26s 37ms/step - accuracy: 0.6154 - loss: 0.6390 - val_accuracy: 0.7399 - val_loss: 0.5286
# Epoch 2/3
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 24s 35ms/step - accuracy: 0.7459 - loss: 0.5112 - val_accuracy: 0.7643 - val_loss: 0.4973
# Epoch 3/3
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 25s 35ms/step - accuracy: 0.7910 - loss: 0.4445 - val_accuracy: 0.7739 - val_loss: 0.4763
# 3-conv-32-nodes-1-dense-1729832922
# Epoch 1/3
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 25s 34ms/step - accuracy: 0.5911 - loss: 0.6565 - val_accuracy: 0.7303 - val_loss: 0.5339
# Epoch 2/3
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 24s 35ms/step - accuracy: 0.7500 - loss: 0.5159 - val_accuracy: 0.7864 - val_loss: 0.4599
# Epoch 3/3
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 25s 35ms/step - accuracy: 0.7843 - loss: 0.4593 - val_accuracy: 0.7988 - val_loss: 0.4454
# 1-conv-64-nodes-1-dense-1729832997
# Epoch 1/3
# 490/702 ━━━━━━━━━━━━━━━━━━━━ 10s 48ms/step - accuracy: 0.5484 - loss: 0.8320
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[29], line 47
#      44 model.add(Activation("sigmoid"))
#      46 model.compile(optimizer="adam", loss= "binary_crossentropy",metrics=["accuracy"])
# ---> 47 model.fit(x,y, batch_size= 32 , validation_split= 0.1, epochs = 3, callbacks=[tensorboard])
#
# File ~\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:320, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     318 for step, iterator in epoch_iterator.enumerate_epoch():
#     319     callbacks.on_train_batch_begin(step)
# --> 320     logs = self.train_function(iterator)
#     321     callbacks.on_train_batch_end(step, logs)
#     322     if self.stop_training:
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\eager\context.py:1552, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1550 cancellation_context = cancellation.context()
#    1551 if cancellation_context is None:
# -> 1552   outputs = execute.execute(
#    1553       name.decode("utf-8"),
#    1554       num_outputs=num_outputs,
#    1555       inputs=tensor_inputs,
#    1556       attrs=attrs,
#    1557       ctx=self,
#    1558   )
#    1559 else:
#    1560   outputs = execute.execute_with_cancellation(
#    1561       name.decode("utf-8"),
#    1562       num_outputs=num_outputs,
#    (...)
#    1566       cancellation_manager=cancellation_context,
#    1567   )
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
model.save("VG.keras")
